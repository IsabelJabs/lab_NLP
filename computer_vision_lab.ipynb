# %% [markdown]
# # Ethical issues with computer vision applications

# %% [markdown]
# ### [Facial Recognition Research Article](https://www.nature.com/articles/d41586-020-03187-3)

# %% [markdown]
# ### The article is about a computer vision facial recognition software, which detects the muslim minority Uyghur in China out of pictures from other people. A minority that is being haunted, suppressed and unvoluntarily send to labour centers.
# ### "China had already been internationally condemned for its heavy surveillance and mass detentions of Uyghurs in camps in the northwestern province of Xinjiang — which the government says are re-education centres aimed at quelling a terrorist movement. According to media reports, authorities in Xinjiang have used surveillance cameras equipped with software attuned to Uyghur faces."

# %% [markdown]
# ### I think the example above is a very cruel drastic example on how AI can be used in the worst way to support discriminative government actions. But shows how far things can go. The idea of the people using the software is the big ethical problem and the software gives them a tool.
# ### There are other examples of computer vision applications where the intention is not a bad one and just e.g. to make a work process efficient, but violates privacy rights of people.

# %% [markdown]
# # Generating an image from a caption

# %% [markdown]
# ### Caption (own): people standing in front of a skyscraper

# %%
# %matplotlib inline
from IPython.display import Image
Image('generated_image.png')

# %% [markdown]
# ### Looks a bit like a Gaudi building :)

# %% [markdown]
# ### Caption "Clock Tower":
# ### A large painted clock tower in the middle of town

# %%
Image('clocktower.png')

# %% [markdown]
# ### A large painted clock tower in the middle of town *with people in front*. I added 'with people in front'.

# %%
Image('clocktowerpeople.png')
